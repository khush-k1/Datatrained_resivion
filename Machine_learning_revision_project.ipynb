# %%
import pandas as pd
import numpy as np


import warnings
warnings.filterwarnings('ignore')

# %%
# getting data set

df= pd.read_csv('https://raw.githubusercontent.com/training-ml/Files/main/raw_data.csv')

df.head()
# Out:
#       id Employee Full Name         DOB                         email  gender  \
# 0  201.0        Salim Pound  02-12-2018           spound0@spotify.com    Male
# 1  202.0     Madelene Lutas   9/20/2018                mlutas1@si.edu  Female
# 2  203.0   Dolli Swanbourne  11/18/2018  dswanbourne2@istockphoto.com  Female
# 3  204.0    Graeme Croisier   9/29/2018                           NaN    Male
# 4  205.0     Jillana Physic   4/19/2018       jphysic4@yellowbook.com  Female
#
#      Company Country           Income.1  Income.2
# 0     Google   India  $46476.6380809961     529.0
# 1     Amazon     USA  $54174.6879482406     720.0
# 2      Intel     UAS                NaN     234.0
# 3  Accenture  Canada  $46784.6308786279     657.0
# 4  Accenture     NaN  $57486.4955595568    1947.0

# %%
# dimension
df.shape
# Out:
# (20, 9)

# %%
# information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  19 non-null     float64
#  1   Employee Full Name  19 non-null     object
#  2   DOB                 19 non-null     object
#  3   email               17 non-null     object
#  4   gender              19 non-null     object
#  5   Company             19 non-null     object
#  6   Country             17 non-null     object
#  7   Income.1            15 non-null     object
#  8   Income.2            17 non-null     float64
# dtypes: float64(2), object(7)
# memory usage: 1.5+ KB

# %% [markdown]
# We can see that some of the data is missing in email, Country, Income.1, Income.2
#
# Most of our columns are object data type except id and Income.2
#
# Let's see entire dataset once before moving forward with this data set.

# %%
# checking entire dataset
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                            NaN
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                            NaN
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9     NaN                  NaN         NaN                            NaN
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %% [markdown]
# As we can see that index 9 has all null values. So we need to fill them with provided data. Also Income.1 is having numerical values with $ on it which makes them categorical column.
#
# Q1. Add Below information as index 9.
#
# 210, 'Jim Carry', 1/1/1970, 'jim.carry@gmail.com', 'Male', 'Amazon', 'USA', 12349.556, 2365

# %%
df.loc[9]= (210, 'Jim Carry', '1/1/1970','jim.carry@gmail.com', 'Male', 'Amazon','USA','$12349.556', 2365)

df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                            NaN
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                            NaN
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
#Q2.add email at 3rd and 6th index position 'graeme.croisier@gmail.com', 'modesta.batterson@gmail.com' respectively

df.at[3, 'email'] ='graeme.croisier@gmai.com'
df.at[6, 'email'] = 'modesta.batterson@gmail.com'

df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018       graeme.croisier@gmai.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
# Q3. If any country is invalid change it to valid country and also fill nan

df['Country'].unique()
# Out:
# array(['India', 'USA', 'UAS', 'Canada', nan, 'Russia'], dtype=object)

# %% [markdown]
# we can see UAS looks like its a typo error, so we change it to USA. also we have nan so we can fill it with mode of this column as it is an categorical column.

# %%
# replacing UAS to USA
df['Country'].replace({'UAS': 'USA'}, inplace= True)
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018       graeme.croisier@gmai.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
# replacing Nan with mode value
df['Country'].fillna(value= df['Country'].mode()[0], inplace=True)

df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018       graeme.croisier@gmai.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %% [markdown]
# # Q4. Add total income column which is submission of Income.1 and Income.2
#
#
# let's start with Income.1 as we have clear Nan and blank $ in it.

# %%
# checking values of Income.1
df['Income.1'].unique()
# Out:
# array(['$46476.6380809961', '$54174.6879482406', nan, '$46784.6308786279',
#        '$57486.4955595568', '$', '$28602.4353770562', '$12349.556',
#        '$47119.1747795038', '$55804.9256874294', '$44191.4731284524',
#        '$44481.7651905881', '$55719.9621570482', '$33767.5099948119',
#        '$7101.35196996979', '$43363.0787072359'], dtype=object)

# %% [markdown]
# we can see their is $ sign which we need to remove in order to make it an int column.

# %%
df['Income.1'].dtype
# Out:
# dtype('O')

# %%
#replacing $ 
df['Income_1']= df['Income.1'].str.replace('$','')

# %%
# Since we have two just $ sign which we replace with black space.. We just assume they don't have ny Income_1 so assign 0.
df['Income_1']= df['Income_1'].replace('','0')

df['Income_1']
# Out:
# 0     46476.6380809961
# 1     54174.6879482406
# 2                  NaN
# 3     46784.6308786279
# 4     57486.4955595568
# 5                    0
# 6                  NaN
# 7                  NaN
# 8     28602.4353770562
# 9            12349.556
# 10    47119.1747795038
# 11                 NaN
# 12    55804.9256874294
# 13    44191.4731284524
# 14                   0
# 15    44481.7651905881
# 16    55719.9621570482
# 17    33767.5099948119
# 18    7101.35196996979
# 19    43363.0787072359
# Name: Income_1, dtype: object

# %%
#converting INcome_1 to numerical form
df['Income_1']= df['Income_1'].astype(float)

df['Income_1'].dtypes
# Out:
# dtype('float64')

# %%
# replacing Nan value with mean 
df['Income_1'].fillna(value= df['Income_1'].mean(), inplace=True)

#chceking dataset
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018       graeme.croisier@gmai.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
# let's drop Income.1 column as werecover this column in Income_1.

df.drop('Income.1', axis= 1, inplace= True)

df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018       graeme.croisier@gmai.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
# let's fill Nan value for Income.2 column with its mean.

df['Income.2'].fillna(value= df['Income.2'].mean(), inplace=True)

df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018       graeme.croisier@gmai.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
# Adding Total Income column

df['Total_Income']= df['Income_1'] + df['Income.2']

df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018       graeme.croisier@gmai.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %% [markdown]
# # 15/9 questions
#
# Q1. Bring DOB in same format

# %%
# Bringing DOB column in same format.
df['DOB']= df['DOB'].apply(lambda x: x.replace('-','/'))

# %%
# converting DOB column to Date format
df['DOB']= pd.to_datetime(df['DOB'])

df
# Out:
#        id First_Name    Last_Name        DOB                          email  \
# 0   201.0      Salim        Pound 2018-02-12            spound0@spotify.com
# 1   202.0   Madelene        Lutas 2018-09-20                 mlutas1@si.edu
# 2   203.0      Dolli   Swanbourne 2018-11-18   dswanbourne2@istockphoto.com
# 3   204.0     Graeme     Croisier 2018-09-29       graeme.croisier@gmai.com
# 4   205.0    Jillana       Physic 2018-04-19        jphysic4@yellowbook.com
# 5   206.0     Anetta     Yokelman 2018-04-26        ayokelman5@berkeley.edu
# 6   207.0    Modesta    Batterson 2018-03-28    modesta.batterson@gmail.com
# 7   208.0     Melina         Boon 2017-12-18               mboon7@weibo.com
# 8   209.0       Nomi         Warn 2018-01-16               nwarn8@sogou.com
# 9   210.0        Jim        Carry 1970-01-01            jim.carry@gmail.com
# 10  211.0   Charleen        Auden 2018-04-15                caudena@nba.com
# ...

# %% [markdown]
# Now entire DOB is in same format. which is yyyy-mm-dd format

# %%
# Q.5 Split full name into first and second name(First name and last name)
df['First_Name']= df['Employee Full Name'].apply(lambda x: x.split(' ')[0])
df['Last_Name'] = df['Employee Full Name'].apply(lambda x: x.split(' ')[1])

#checking dataset
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02/12/2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018       graeme.croisier@gmai.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
# dropping employee full name column

df.drop('Employee Full Name', axis= 1, inplace= True)
df
# Out:
#        id         DOB                          email  gender    Company  \
# 0   201.0  02/12/2018            spound0@spotify.com    Male     Google
# 1   202.0   9/20/2018                 mlutas1@si.edu  Female     Amazon
# 2   203.0  11/18/2018   dswanbourne2@istockphoto.com  Female      Intel
# 3   204.0   9/29/2018       graeme.croisier@gmai.com    Male  Accenture
# 4   205.0   4/19/2018        jphysic4@yellowbook.com  Female  Accenture
# 5   206.0   4/26/2018        ayokelman5@berkeley.edu  Female      Intel
# 6   207.0   3/28/2018    modesta.batterson@gmail.com  Female      Intel
# 7   208.0  12/18/2017               mboon7@weibo.com    Male     Amazon
# 8   209.0   1/16/2018               nwarn8@sogou.com  Female     Amazon
# 9   210.0    1/1/1970            jim.carry@gmail.com    Male     Amazon
# 10  211.0   4/15/2018                caudena@nba.com  Female  Accenture
# 11  212.0   6/26/2018         dpoveleb@bloglovin.com    Male     Amazon
# ...

# %%
# Q. Shift First and Last Name column after id 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20 non-null     float64
#  1   DOB           20 non-null     object
#  2   email         20 non-null     object
#  3   gender        20 non-null     object
#  4   Company       20 non-null     object
#  5   Country       20 non-null     object
#  6   Income.2      20 non-null     float64
#  7   Income_1      20 non-null     float64
#  8   Total_Income  20 non-null     float64
#  9   First_Name    20 non-null     object
#  10  Last_Name     20 non-null     object
# dtypes: float64(4), object(7)
# memory usage: 1.8+ KB

# %% [markdown]
# From here we can see the index positions of columns. by using iloc we can rearrange columns.

# %%
# rearranged dataset.

df=df.iloc[:, [0,9,10,1,2,3,4,5,7,6,8]]

df
# Out:
#        id First_Name    Last_Name         DOB                          email  \
# 0   201.0      Salim        Pound  02/12/2018            spound0@spotify.com
# 1   202.0   Madelene        Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0      Dolli   Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0     Graeme     Croisier   9/29/2018       graeme.croisier@gmai.com
# 4   205.0    Jillana       Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0     Anetta     Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta    Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0     Melina         Boon  12/18/2017               mboon7@weibo.com
# 8   209.0       Nomi         Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0        Jim        Carry    1/1/1970            jim.carry@gmail.com
# 10  211.0   Charleen        Auden   4/15/2018                caudena@nba.com
# ...

# %% [markdown]
# Now our dataset is aaranged in the desire form.

# %%
# print country and companywise average salary(total income) of employees.

# let's import necessary libraries

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.catplot(x='Country', y='Total_Income', data=df, hue='Company',kind= 'boxen', height=5, aspect=4)
plt.title("Country and Companywise average salary of employees")
# Out:
# Text(0.5, 1.0, 'Country and Companywise average salary of employees')

# %%
plt.figure(figsize=(10,6))
df.groupby(['Country','Company']).Total_Income.mean().plot.bar(ylim=0)
plt.ylabel('Total_Income')
plt.title("Country and Companywise average total income.")
plt.show()

# %%
df.describe()   # statistical description
# Out:
#               id      Income_1     Income.2  Total_Income
# count   20.00000     20.000000    20.000000     20.000000
# mean   210.50000  36088.980341  1125.722222  37214.702563
# std      5.91608  18008.941015   685.225342  17918.014037
# min    201.00000      0.000000    32.000000    568.000000
# 25%    205.75000  32476.241340   634.750000  34197.671896
# 50%    210.50000  39726.029524  1069.361111  41113.726735
# 75%    215.25000  46868.266854  1726.250000  47591.016854
# max    220.00000  57486.495560  2365.000000  59433.495560
